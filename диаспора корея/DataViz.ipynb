# %%
# !pip install gensim
import gensim
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
import pandas as pd
# !pip install wordcloud
from wordcloud import WordCloud
! pip install adjustText
from sklearn.manifold import TSNE
import numpy as np
from adjustText import adjust_text
from sklearn.cluster import KMeans
import plotly.graph_objects as go
import plotly.express as px
from collections import Counter

# %%
korea_df = pd.read_csv('/content/out.csv')

# %%
korea_df.head()

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('korea.bin', binary=True)

# %%
freq_tokens_kr = model.key_to_index
words_kr = list(freq_tokens_kr.keys())[:200]
print(words_kr)

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(freq_tokens_kr)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
fpath = "/content/NanumGothic-Regular.ttf"

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white', font_path=fpath).generate_from_frequencies(freq_tokens_kr)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
font_prop1 = FontProperties(fname=fpath)
font_prop = FontProperties(fname=fpath, size=10)

# %%
word_vectors = np.array([model[word] for word in words_kr])
word_vectors

tsne = TSNE(n_components=2, random_state=17, perplexity=30, n_iter=1000)
tsne_vectors = tsne.fit_transform(word_vectors)
tsne_vectors[:10]

n_clusters = 5
kmeans = KMeans(n_clusters=n_clusters, random_state=17)
clusters = kmeans.fit_predict(word_vectors)
print(clusters)
print(len(clusters))

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
plt.figure(figsize=(14, 12))
for i, word in enumerate(words_kr):
    x, y = tsne_vectors[i, :]
    plt.scatter(x, y, c=[plt.cm.Spectral(clusters[i] / n_clusters)], marker='o', alpha=0.6)
    plt.text(x + 0.1, y + 0.1, word, fontsize=10, fontproperties=font_prop)

plt.title("Топ-200 слов")
plt.show()

# %%
words_kr_100 = list(freq_tokens_kr.keys())[:100]
print(words_kr_100)

# %%
fig = go.Figure()
for i, word in enumerate(words_kr):
    x, y = tsne_vectors[i, :]
    color = px.colors.qualitative.Plotly[clusters[i] % len(px.colors.qualitative.Plotly)]
    fig.add_trace(
        go.Scatter(
            x=[x],
            y=[y],
            #mode="markers", #если не нужны надписи, то раскомментировать это, а закомментировать следующее
            mode="markers+text",
            text=[word],
            textposition="top center",
            marker=dict(size=8, color=color, opacity=0.7),
            hovertemplate=f"Слово: {word}<br>Кластер: {clusters[i]}<br>t-SNE 1: {x:.2f}<br>t-SNE 2: {y:.2f}",
            textfont=dict(family=font_prop1.get_name(), size=12)
        )
    )

fig.update_layout(
    title="Топ-200 слов",
    showlegend=False,
    hovermode="closest",
    width=1000,
    height=800,
    template="plotly_white"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="69aff14b-4669-4319-9d8c-52f4599297a5" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69aff14b-4669-4319-9d8c-52f4599297a5")) {                    Plotly.newPlot(                        "69aff14b-4669-4319-9d8c-52f4599297a5",                        [{"hovertemplate":"Слово: 월\u003cbr\u003eКластер: 0\u003cbr\u003et-SNE 1: -2.99\u003cbr\u003et-SNE 2: 5.71","marker":{"color":"#636EFA","opacity":0.7,"size":8},"mode":"markers+text","text":["월"],"textfont":{"family":"NanumGothic","size":12},"textposition":"top center","x":[-2.9949779510498047],"y":[5.707230567932129],"type":"scatter"},{"hovertemplate":"Слово: 있다\u003cbr\u003eКластер: 3\u003cbr\u003et-SNE 1: -4.48\u003cbr\u003et-SNE 2: 0.05","marker":{"color":"#AB63FA","opacity":0.7,"size":8},"mode":"markers+text","text":["있다"],"textfont":{"family":"NanumGothic","size":12},"textposition":"top center","x":[-4.4794464111328125],"y":[0.05447227880358696],"type":"scatter"},{"hovertemplate":"Слово: 그는\u003cbr\u003eКластер: 3\u003cbr\u003et-SNE 1: -2.01\u003cbr\u003et-SNE 2: 2.05","marker":{"color":"#AB63FA","opacity":0.7,"size":8},"mode":"markers+text","text":["그는"],"textfont":{"family":"NanumGothic","size":12},"textposition":"top center","x":[-2.01363205909729],"y":[2.050583839416504],"type":"scatter"},{"hovertemplate":"Слово: 년\u003cbr\u003eКластер: 3\u003cbr\u003et-SNE 1: -2.53\u003cbr\u003et-SNE 2: 4.36","marker":{"color":"#AB63FA","opacity":0.7,"size":8},"mode":"markers+text","text":["년"],"textfont":{"family":"NanumGothic","size":12},"textposition":"top center","x":[-2.531491279602051],"y":[4.3578410148620605],"type":"scatter"},{"hovertemplate":"Слово: 있는\u003cbr\u003eКластер: 0\u003cbr\u003et-SNE 1: -6.25\u003cbr\u003et-SNE 2: -2.71","marker":{"color":"#636EFA","opacity":0.7,"size":8},"mode":"markers+text","text":["있는"],"textfont":{"family":"NanumGothic","size":12},"textposition":"top center","x":[-6.247963905334473],"y":[-2.7085790634155273],"type":"scatter"},{"hovertemplate":"Слово: 일\u003cbr\u003eКластер: 1\u003cbr\u003et-SNE 1: -5.58\u003cbr\u003et-SNE 2: 3.68","marker":{"color":"#EF553B","opacity":0.7,"size":8},"mode":"markers+text","text":["일"],"textfont":{"family":"NanumGothic","size":12},"textposition":"top center","x":[-5.575236797332764],"y":[3.678666830062866],"type":"scatter"},{"hovertemplate":"Слово: 지난\u003cbr\u003eКластер: 4\u003cbr\u003et-SNE 1: -1.85\u003cbr\u003et-SNE 2: 1.72","marker":{"color":"#FFA15A","opacity":0.7,"size":8},"mode":"markers+text","text":["지난"],"textfont":{"family":"NanumGothic","size":12},"textposition":"top center","x":[-1.8532596826553345],"y":[1.7178784608840942],"type":"scatter"},{"hovertemplate":"Слово: 했다\u003cbr\u003eКластер: 2\u003cbr\u003et-SNE 1: 0.67\u003cbr\u003et-SNE 2: -2.29","marker":{"color":"#00CC96","opacity":0.7,"size":8},"mode":"markers+text","text":["했다"],"textfont":{"family":"NanumGothic","size":12},"textposition":"top center","x":[0.6709492802619934],"y":[-2.2875099182128906],"type":"scatter"},{"hovertemplate":"Слово: 수\u003cbr\u003eКластер: 3\u003cbr\u003et-SNE 1: -0.36\u003cbr\u003et-SNE 2: -5.04","marker":{"color":"#AB63FA","opacity":0.7,"size":8},"mode":"markers+text","text":["수"],"textfont":{"family":"NanumGothic","size":12},"textposition":"top center","x":[-0.36366987228393555],"y":[-5.03984260559082],"type":"scatter"},{"hovertemplate":"Слово: 이\u003cbr\u003eКластер: 1\u003cbr\u003et-SNE 1: 3.94\u003cbr\u003et-SNE 2: 4.77","marker":{"color":"#EF553B","opacity":0.7,"size":8},"mode":"markers+text","text":["이"],"textfont":{"family":"NanumGothic","size":12},"textposition":"top center","x":[3.942899465560913],"y":[4.7673115730285645],"type":"scatter"},{"hovertemplate":"Слово: 회장은\u003cbr\u003eКластер: 0\u003cbr\ ...

# %%
top_words = [tupl[0] for tupl in model.most_similar(['문화','대한'], topn=20)]
print(top_words)

# %%
words = top_words + ['문화','대한']
vectors = [model[word] for word in words]
vectors = np.array(vectors)
tsne = TSNE(n_components=2, random_state=42, perplexity=5)
vectors_2d = tsne.fit_transform(np.array(vectors))
plt.figure(figsize=(10, 6))
texts = []
colors = plt.cm.tab20(np.linspace(0, 1, len(words)))
for i, word in enumerate(words):
    plt.scatter(
        vectors_2d[i, 0], vectors_2d[i, 1],
        c=[colors[i]], s=100, marker='o',
        alpha=0.7
    )
    texts.append(
        plt.text(
            vectors_2d[i, 0] + 0.5, vectors_2d[i, 1] + 0.5,
            word, fontsize=12, fontproperties=font_prop
        )
    )

adjust_text(texts, arrowprops=dict(arrowstyle='-', color='gray', lw=0.5)) #укладка и подрисовка стрелочек

plt.title("Ближайшие соседи слов 'культура','Корея' в южнокорейских статьях о диаспорах",
          fontsize=16, fontfamily='Arial Unicode MS', pad=15, weight='bold')
plt.tight_layout()
plt.show()
